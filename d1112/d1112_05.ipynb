# %%
import matplotlib.pyplot as plt
#한글설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #win 용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스

# %%
import pandas as pd
import random
df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
# x축 : 지원번호 y축 국어
# 선색상 red 마커색상 yellow 테두리 blue,,  선타입 --

# %%
x= df.index
k= df['국어']
e= df['영어']
m= df['수학']


plt.plot(x,k,marker='o',mfc='yellow',ls='--')
plt.plot(x,e,marker='v',mfc='yellow',ls='--')
plt.plot(x,m,marker='x',mfc='yellow',ls='--')
